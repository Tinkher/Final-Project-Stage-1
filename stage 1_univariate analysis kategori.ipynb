# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# Mengambil file CSV dengan Pandas
df = pd.read_csv('dataset_baru.csv')

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may     261.0       1.0   -1.0       0.0  unknown  no
# 1  unknown    5   may     151.0       1.0   -1.0       0.0  unknown  no
# 2  unknown    5   may      76.0       1.0   -1.0       0.0  unknown  no
# 3  unknown    5   may      92.0       1.0   -1.0       0.0  unknown  no
# 4  unknown    5   may     198.0       1.0   -1.0       0.0  unknown  no

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45663.000000   45663.000000  45663.000000  45317.000000  45281.000000
# mean      40.937389    1363.058012     15.811248    258.226582      2.764250
# std       10.616812    3049.909173      8.319972    257.642594      3.097611
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     449.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.500000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45446.000000  45395.000000
# mean      40.166857      0.579667
# std      100.063270      2.303390
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45663 entries, 0 to 45662
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45663 non-null  int64
#  1   job        45663 non-null  object
#  2   marital    45663 non-null  object
#  3   education  45663 non-null  object
#  4   default    45663 non-null  object
#  5   balance    45663 non-null  int64
#  6   housing    45663 non-null  object
#  7   loan       45663 non-null  object
#  8   contact    45663 non-null  object
#  9   day        45663 non-null  int64
#  10  month      45663 non-null  object
#  11  duration   45317 non-null  float64
#  12  campaign   45281 non-null  float64
#  13  pdays      45446 non-null  float64
#  14  previous   45395 non-null  float64
#  15  poutcome   45663 non-null  object
#  16  y          45355 non-null  object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 5.9+ MB

# %%
# Out:
#                 job  marital  education default housing   loan   contact  \
# count         45663    45663      45663   45663   45663  45663     45663
# unique           12        3          4       2       2      2         3
# top     blue-collar  married  secondary      no     yes     no  cellular
# freq           9816    27473      23418   44839   25380  38350     29574
#
#         month poutcome      y
# count   45663    45663  45355
# unique     12        4      2
# top       may  unknown     no
# freq    13910    37344  40055

# %%
 cat = []
 num = []
 for column in df.columns:
    if df [column].nunique() > 12:
        num.append(column)
    else:1
    cat.append(column)

# %%
cat
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
df[cats].describe()
# Out:
#                 job  marital  education default housing   loan   contact  \
# count         45663    45663      45663   45663   45663  45663     45663
# unique           12        3          4       2       2      2         3
# top     blue-collar  married  secondary      no     yes     no  cellular
# freq           9816    27473      23418   44839   25380  38350     29574
#
#         month poutcome      y
# count   45663    45663  45355
# unique     12        4      2
# top       may  unknown     no
# freq    13910    37344  40055

# %%
for cat in cats:
  print('Category: ', cat)
  display((df[cat].value_counts() / len(df) * 100)[:10])
  print()
# Out:
# Category:  job
# blue-collar      21.496617
# management       20.949127
# technician       16.827628
# admin.           11.429385
# services          9.169349
# retired           5.021571
# self-employed     3.479841
# entrepreneur      3.291505
# unemployed        2.873223
# housemaid         2.746206
# Name: job, dtype: float64
# Category:  marital
# married     60.164685
# single      28.311762
# divorced    11.523553
# Name: marital, dtype: float64
# Category:  education
# secondary    51.284410
# tertiary     29.452730
# primary      15.141362
# unknown       4.121499
# Name: education, dtype: float64
# Category:  default
# no     98.195476
# yes     1.804524
# Name: default, dtype: float64
# Category:  housing
# yes    55.581105
# no     44.418895
# Name: housing, dtype: float64
# Category:  loan
# no     83.984845
# yes    16.015155
# Name: loan, dtype: float64
# Category:  contact
# cellular     64.765784
# unknown      28.800123
# telephone     6.434093
# ...

# %%
for cat in cats:
    plt.figure(figsize=(8, 6))  
    sns.countplot(data=df, x=cat)
    plt.title('Distribusi ' + cat)
    plt.xlabel(cat)
    plt.ylabel('Frekuensi')
    plt.xticks(rotation=45)  
    plt.show()

# %% [markdown]
# Penjelasan terhadap data diatas:
# 1. Job Distribution: Mayoritas responden memiliki pekerjaan di bidang blue-collar, management, dan technician,sementara pekerjaan di bidang housemaid, self-employed, dan entrepreneur memiliki jumlah yang lebih sedikit.
# 2. Status Marital: Sebagian besar responden adalah yang sudah menikah, sementara jumlah responden
#     yang single atau bercerai lebih sedikit.
# 3. Pendidikan: Sebagian besar responden memiliki pendidikan tingkat sekunder, diikuti oleh tingkat pendidikan tertier,
#     sementara jumlah responden dengan pendidikan primer atau pendidikan tidak diketahui lebih sedikit.
# 4. Default: Mayoritas responden tidak memiliki catatan gagal pembayaran (default),
#     dengan hanya sebagian kecil yang memiliki catatan default.
# 5. Housing dan Loan: Mayoritas responden memiliki pinjaman rumah (housing loan)
#     dan mayoritas juga tidak memiliki pinjaman (loan).
# 6. Kontak: Komunikasi dengan responden sebagian besar dilakukan melalui telepon seluler (cellular),
#     sedangkan jumlah yang menggunakan kontak yang tidak diketahui atau melalui telepon konvensional lebih sedikit.
# 7. Month: Waktu pelaksanaan kampanye pemasaran terpusat di bulan Mei, dengan penyebaran yang signifikan
#     pada bulan Juli dan Agustus, dan penyebaran yang lebih rendah pada bulan-bulan lainnya.
# 8. Outcome of the Previous Marketing Campaign (Poutcome): Mayoritas hasil dari kampanye pemasaran sebelumnya tidak diketahui,
#     sementara hasil-hasil positif seperti 'success' dan 'other' memiliki persentase yang lebih rendah.
# 9. Outcome Target (y): Mayoritas responden tidak berlangganan produk/jasa yang ditawarkan dalam kampanye pemasaran tersebut.
